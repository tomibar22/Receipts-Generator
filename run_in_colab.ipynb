# %% [markdown]
# # Receipts Generator
# Run this notebook to generate receipts for the previous month.
#
# **Step 1:** Run the cell below to clone the repo and install dependencies.

# %%
# !git clone https://github.com/tomibar22/Receipts-Generator.git
# %cd Receipts-Generator
# !pip install -q -r requirements.txt

# %% [markdown]
# **Step 2:** Run the cell below to set your credentials (already filled in).

# %%
# %%writefile .env
# NOTION_SECRET=secret_4Sf91PbLDjIVqdyBI64iKYy1FfkHNxVgrTN809qT6g5
# MORNING_SECRET=rtPIk4pW3mP-7daFgUttmQ
# MORNING_ID=828db717-aebf-4e58-a498-4218c51a827a
# DATABASE_ID=c18b4103b7a043018c695a7929f17ac3

# %% [markdown]
# **Step 3:** Run the cell below to generate receipts for the previous month.

# %%
# !python main.py
